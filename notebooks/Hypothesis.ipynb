# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('complexity_utf-16_4243_20_10_bibles_90_lcm.csv', index_col=False)

# %%
import seaborn as sns

# %%
def plot_as_coisas(df):
    for m in df.metric.unique():
        for alg in in df.algorithm.unique():
            current = df.loc[df.metric == m]
            current = current.loc[current.algorithm == alg]
            sns.histplot(current.

# %%
#color = []
m2i = {'del-verses' : 'blue', 
       'del-words' : 'red',
       'del-chars' : 'black',
       'rep-words' : 'green',
      }

#for row in df:
#    color.append(m2i[row['metric']])

c = df.metric.map(m2i)
pd.options.mode.copy_on_write = True
df['color'] = c

x = df.loc[df['algorithm'] == 'gzip']
y = df.loc[df.algorithm == 'bz2']
c = df.loc[df.algorithm == 'bz2']['color']

# %%
idy = y.loc[y.color == 'black']['value']
idx = x.loc[x.color == 'black']['value']
plt.scatter(idx, idy)

# %%
raw = df[(df.metric == 'do-nothing') & ((df.algorithm == 'bz2') | (df.algorithm == 'gzip'))]

# %%
raw
# Out:
#            language   wals      metric algorithm     value  run_id color
# 3240  ANCIENT_GREEK  [grc]  do-nothing      gzip  358643.0       0   NaN
# 3241  ANCIENT_GREEK  [grc]  do-nothing      gzip  358643.0       1   NaN
# 3242  ANCIENT_GREEK  [grc]  do-nothing      gzip  358643.0       2   NaN
# 3243  ANCIENT_GREEK  [grc]  do-nothing      gzip  358643.0       3   NaN
# 3244  ANCIENT_GREEK  [grc]  do-nothing      gzip  358643.0       4   NaN
# ...             ...    ...         ...       ...       ...     ...   ...
# 3775       YANOMAMI  [guu]  do-nothing       bz2  276517.0       5   NaN
# 3776       YANOMAMI  [guu]  do-nothing       bz2  276517.0       6   NaN
# 3777       YANOMAMI  [guu]  do-nothing       bz2  276517.0       7   NaN
# 3778       YANOMAMI  [guu]  do-nothing       bz2  276517.0       8   NaN
# 3779       YANOMAMI  [guu]  do-nothing       bz2  276517.0       9   NaN
#
# [540 rows x 7 columns]

# %%
len(raw.language.unique())
# Out:
# 27

# %%
plt.xticks(rotation=90)
# Out:
# (array([0. , 0.2, 0.4, 0.6, 0.8, 1. ]),
#  [Text(0.0, 0, '0.0'),
#   Text(0.2, 0, '0.2'),
#   Text(0.4, 0, '0.4'),
#   Text(0.6000000000000001, 0, '0.6'),
#   Text(0.8, 0, '0.8'),
#   Text(1.0, 0, '1.0')])

# %%
sns.violinplot(data=raw, x="language", y="value", hue="algorithm", split=True, inner="quart")
# Out:
# <Axes: xlabel='language', ylabel='value'>

# %%
raw_gzip = raw[raw.algorithm == 'gzip']
raw_bz2 = raw[raw.algorithm == "bz2"]

# %%
raw_gzip[raw_gzip.value == raw_gzip.value.min()]
# Out:
#        language   wals      metric algorithm     value  run_id color
# 3410  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       0   NaN
# 3411  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       1   NaN
# 3412  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       2   NaN
# 3413  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       3   NaN
# 3414  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       4   NaN
# 3415  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       5   NaN
# 3416  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       6   NaN
# 3417  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       7   NaN
# 3418  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       8   NaN
# 3419  NHEENGATU  [yrl]  do-nothing      gzip  281693.0       9   NaN

# %%
raw_bz2.drop_duplicates(subset=["language"]).sort_values("value")
# Out:
#                       language   wals      metric algorithm     value  run_id  \
# 3680                 NHEENGATU  [yrl]  do-nothing       bz2  171128.0       0
# 3620                  JAMAMADI    jmm  do-nothing       bz2  185724.0       0
# 3590              GUARANI_MBYA  [gun]  do-nothing       bz2  193991.0       0
# 3580  GUARANI_EASTERN_BOLIVIAN    crg  do-nothing       bz2  197677.0       0
# 3610  GUARANI_WESTERN_BOLIVIAN  [gnw]  do-nothing       bz2  198958.0       0
# 3600          GUARANI_PARAGUAY    gua  do-nothing       bz2  203361.0       0
# 3550                   ENGLISH    eng  do-nothing       bz2  204570.0       0
# 3710                PORTUGUESE    por  do-nothing       bz2  205972.0       0
# 3660                  MAXAKALI    max  do-nothing       bz2  207666.0       0
# 3560                    FRENCH    fre  do-nothing       bz2  217204.0       0
# 3570                   GERMANY    ger  do-nothing       bz2  219739.0       0
# ...

# %%
raw_gzip.drop_duplicates(subset=['language']).sort_values('value')
# Out:
#                       language   wals      metric algorithm     value  run_id  \
# 3410                 NHEENGATU  [yrl]  do-nothing      gzip  281693.0       0
# 3350                  JAMAMADI    jmm  do-nothing      gzip  304213.0       0
# 3320              GUARANI_MBYA  [gun]  do-nothing      gzip  314525.0       0
# 3310  GUARANI_EASTERN_BOLIVIAN    crg  do-nothing      gzip  317348.0       0
# 3340  GUARANI_WESTERN_BOLIVIAN  [gnw]  do-nothing      gzip  320375.0       0
# 3440                PORTUGUESE    por  do-nothing      gzip  321657.0       0
# 3330          GUARANI_PARAGUAY    gua  do-nothing      gzip  328258.0       0
# 3390                  MAXAKALI    max  do-nothing      gzip  331121.0       0
# 3280                   ENGLISH    eng  do-nothing      gzip  334854.0       0
# 3290                    FRENCH    fre  do-nothing      gzip  353331.0       0
# 3300                   GERMANY    ger  do-nothing      gzip  357406.0       0
# ...

# %%
def get_indexes(df):
    langs = df.drop_duplicates("language").sort_values("value").language
    ret = {
        col : i
    for i, col in enumerate(langs)
    }
    return ret

# %%
def get_values(df):
    langs = df.drop_duplicates("language").sort_values("value")
    return langs.loc[:, ["language", "value"]]

# %%
def index_difference(id1, id2):
    ids = id1.keys() & id2.keys()
    ret = {
        i : (id1[i] - id2[i])
        for i in ids
    }
    return ret

# %%
gzipi = get_indexes(raw_gzip)
bz2i = get_indexes(raw_bz2)

# %%
index_difference(gzipi, bz2i)
# Out:
# {'TUYÚCA': 3,
#  'JAMAMADI': 0,
#  'GUARANI_MBYA': 0,
#  'SPANISH': 0,
#  'PALIKÚR': 0,
#  'PARECÍS': 0,
#  'MACUSHI': 0,
#  'ANCIENT_GREEK': -2,
#  'TERÊNA': 0,
#  'APURINÃ': -1,
#  'GERMANY': 0,
#  'FRENCH': 0,
#  'PORTUGUESE': -2,
#  'YANOMAMI': 0,
#  'APALAÍ': -2,
#  'GUARANI_WESTERN_BOLIVIAN': 0,
#  'KAIGANG': 0,
#  'GUARANI_PARAGUAY': 1,
#  'MATSÉS': 1,
#  'NADEB': 2,
#  'ASHENINKA': -1,
#  'ENGLISH': 2,
#  'SATERÉ-MAWÉ': 0,
#  'NHEENGATU': 0,
#  'MAXAKALI': -1,
#  'WAPISHANA': 0,
#  'GUARANI_EASTERN_BOLIVIAN': 0}

# %%
gzip_series = pd.Series([ gzipi[x] for x in sorted(gzipi) ])
bz2_series = pd.Series([ bz2i[x] for x in sorted(bz2i)])

# %%
gzip_series.corr(bz2_series, method='pearson')
# Out:
# 0.9896214896214895

# %%
bibles = pd.read_csv('../dataset/bibles_90_lcm.csv')

# %%
import sys
sys.path.append('..')
import src.data.util as du
import src.text.tokenizer as tk

# %%
def compute_numtypes_numtokens(df):
    langs = du.by_field(df, 'language')
    united = {
        lang : du.df_to_str(val)
        for lang, val in langs.items()
    }

    d = dict(language=[], tokens=[], types=[])
    for lang, text in united.items():
        d['language'].append(lang)
        tokens = tk.tokens(text)
        d['tokens'].append(len(tokens))
        d['types'].append(len(tk.types(tokens)))
    return d

# %%
d = compute_numtypes_numtokens(bibles)

# %%
tdf = pd.DataFrame(d).sort_values('language')

# %%
def fetch_algorithm(df, metric, algo):
    df2 = df[(df.algorithm == algo) & (df.metric == metric)]
    m = df2.groupby(by=["language"]).value.transform("mean")
    s = df2.groupby(by=["language"]).value.transform("std")
    df2['mean'] = m
    df2['std'] = s
    return df2.drop_duplicates('language').sort_values('language').reset_index().drop(columns='index')

# %%
delwords_gzip = fetch_algorithm(df, 'del-words', 'gzip')
delwords_bz2 = fetch_algorithm(df, 'del-words', 'bz2')

# %%
print(tdf.tokens.corr(delwords_gzip.value, method='pearson'))
print(tdf.types.corr(delwords_gzip.value, method='pearson'))
#delwords_gzip.value.corr(tdf.tokens, method='pearson')
# Out:
# 0.7558404561664755
# -0.7854930628665364

# %%
print(tdf.tokens.corr(delwords_bz2.value, method='pearson'))
print(tdf.types.corr(delwords_bz2.value, method='pearson'))
# Out:
# 0.7650985050234953
# -0.7350736286647962

# %%
df[(df.metric=='do-nothing') & (df.algorithm=='none')]
# Out:
#            language   wals      metric algorithm      value  run_id color
# 3780  ANCIENT_GREEK  [grc]  do-nothing      none  1518436.0       0   NaN
# 3781  ANCIENT_GREEK  [grc]  do-nothing      none  1518436.0       1   NaN
# 3782  ANCIENT_GREEK  [grc]  do-nothing      none  1518436.0       2   NaN
# 3783  ANCIENT_GREEK  [grc]  do-nothing      none  1518436.0       3   NaN
# 3784  ANCIENT_GREEK  [grc]  do-nothing      none  1518436.0       4   NaN
# ...             ...    ...         ...       ...        ...     ...   ...
# 4045       YANOMAMI  [guu]  do-nothing      none  3008434.0       5   NaN
# 4046       YANOMAMI  [guu]  do-nothing      none  3008434.0       6   NaN
# 4047       YANOMAMI  [guu]  do-nothing      none  3008434.0       7   NaN
# 4048       YANOMAMI  [guu]  do-nothing      none  3008434.0       8   NaN
# 4049       YANOMAMI  [guu]  do-nothing      none  3008434.0       9   NaN
#
# [270 rows x 7 columns]
