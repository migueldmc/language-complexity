# %%
import re

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
pd.options.mode.copy_on_write = True

import scipy as sp
import seaborn as sns


import sys
sys.path.append('..')
import src.data.util as du
import src.text.tokenizer as tk

# %% [markdown]
# # Data setup

# %%
data_file = '../results/complexity_utf-16_2020_10_10_bibles_lcm.csv'
bible_file = '../dataset/' + re.match('.*(bibles_.*)', data_file).group(1)

df = pd.read_csv(data_file, index_col=False)
df = df[df.language != 'NAMBIKUÁRA'] # We removed Nambikuára because it has tone annotation
bibles = pd.read_csv(bible_file, index_col=False)
bibles = bibles[bibles.language != 'NAMBIKUÁRA']

raw_gzip = df[(df.metric == "do-nothing") & (df.algorithm == "gzip")]
raw_bz2 = df[(df.metric == "do-nothing") & (df.algorithm == "bz2")]

# %%
df.head()
# Out:
#         language   wals      metric algorithm     value  run_id
# 0  ANCIENT_GREEK  [grc]  del-verses      gzip  0.904723       0
# 1  ANCIENT_GREEK  [grc]  del-verses      gzip  0.909796       1
# 2  ANCIENT_GREEK  [grc]  del-verses      gzip  0.902007       2
# 3  ANCIENT_GREEK  [grc]  del-verses      gzip  0.903372       3
# 4  ANCIENT_GREEK  [grc]  del-verses      gzip  0.908029       4

# %% [markdown]
# # Helper functions

# %%
def get_indexes(df):
    langs = df.drop_duplicates("language").sort_values("value").language
    ret = {
        col : i
    for i, col in enumerate(langs)
    }
    return ret


def index_difference(id1, id2):
    ids = id1.keys() & id2.keys()
    ret = {
        i : (id1[i] - id2[i])
        for i in ids
    }
    return ret


def compute_numtypes_numtokens(df):
    langs = du.by_field(df, 'language')
    united = {
        lang : du.df_to_str(val)
        for lang, val in langs.items()
    }

    d = dict(language=[], tokens=[], types=[])
    for lang, text in united.items():
        d['language'].append(lang)
        tokens = tk.tokens(text)
        d['tokens'].append(len(tokens))
        d['types'].append(len(tk.types(tokens)))
    return d
       

def fetch_algorithm(df, metric, algo):
    df2 = df[(df.algorithm == algo) & (df.metric == metric)]
    by = ["language"]
    m = df2.groupby(by=by).value.transform("mean")
    s = df2.groupby(by=by).value.transform("std")
    df2['mean'] = m
    df2['std'] = s
    return df2.drop_duplicates('language').sort_values('language').reset_index().drop(columns='index')


def fetch_all_metric_algorithms(df):
    by = ["language", "metric", "algorithm"]
    m = df.groupby(by=by).value.transform("mean")
    s = df.groupby(by=by).value.transform("std")
    df2 = df.copy()
    df2["mean"] = m
    df2["var"] = s**2
    return df2.drop_duplicates(by).sort_values('language').reset_index().drop(columns=['index', 'run_id'])

# %% [markdown]
# # H1 Overall complexity of a text
#
# The overall complexity of a text in its
# original language is lower than in the other
# languages, as a result of the introduction
# of cultural clarification in the translation process.
# The language complexity of a translated text should be greater than their counterpart in the source language.

# %%
rg = raw_gzip.drop_duplicates("language").sort_values("value").reset_index().drop(columns="index")

rb = raw_bz2.drop_duplicates("language").sort_values("value").reset_index().drop(columns="index")

sp.stats.pearsonr(rb.sort_values("language").index.to_numpy(), rg.sort_values("language").index.to_numpy())
# Out:
# PearsonRResult(statistic=0.9903622693096377, pvalue=4.745410570962715e-48)

# %%
rg
# Out:
#                     language   wals      metric algorithm     value  run_id
# 0                  NHEENGATU  [yrl]  do-nothing      gzip  106686.0       0
# 1                   JAMAMADI    jmm  do-nothing      gzip  114546.0       0
# 2               GUARANI_MBYA  [gun]  do-nothing      gzip  119424.0       0
# 3   GUARANI_EASTERN_BOLIVIAN    crg  do-nothing      gzip  119444.0       0
# 4   GUARANI_WESTERN_BOLIVIAN  [gnw]  do-nothing      gzip  120323.0       0
# 5                 PORTUGUESE    por  do-nothing      gzip  121637.0       0
# 6           GUARANI_PARAGUAY    gua  do-nothing      gzip  124258.0       0
# 7                   MAXAKALI    max  do-nothing      gzip  125561.0       0
# 8                    ENGLISH    eng  do-nothing      gzip  127418.0       0
# 9                     KARAJÁ    jva  do-nothing      gzip  129697.0       0
# 10                    FRENCH    fre  do-nothing      gzip  133309.0       0
# 11                   GERMANY    ger  do-nothing      gzip  134847.0       0
# 12                 ASHENINKA    cax  do-nothing      gzip  135531.0       0
# 13                   PARECÍS    pex  do-nothing      gzip  136570.0       0
# 14             ANCIENT_GREEK  [grc]  do-nothing      gzip  137000.0       0
# 15                    TUYÚCA    tuy  do-nothing      gzip  137972.0       0
# 16                   SPANISH    spa  do-nothing      gzip  138579.0       0
# 17                   KAIGANG    kng  do-nothing      gzip  141374.0       0
# 18                   SIRIANO    sri  do-nothing      gzip  144731.0       0
# 19                   APURINÃ    apu  do-nothing      gzip  144886.0       0
# 20                    TUCANO    tuc  do-nothing      gzip  149416.0       0
# 21                   APALAÍ    apl  do-nothing      gzip  149740.0       0
# 22                    DESANO    des  do-nothing      gzip  154134.0       0
# 23                     NADEB    nad  do-nothing      gzip  154365.0       0
# 24                    MATSÉS    myr  do-nothing      gzip  155405.0       0
# 25                PIRATAPÚYA    prt  do-nothing      gzip  155746.0       0
# 26                    WANANA    gno  do-nothing      gzip  156814.0       0
# 27                  YAMINÁWA    yam  do-nothing      gzip  158631.0       0
# 28                    BORÔRO    brr  do-nothing      gzip  159727.0       0
# 29                    MAKUNA    mcn  do-nothing      gzip  160067.0       0
# 30                    TICUNA    tic  do-nothing      gzip  161512.0       0
# 31                 WAPISHANA    wps  do-nothing      gzip  163327.0       0
# 32                 KASHINAWA    csh  do-nothing      gzip  165270.0       0
# 33                   KADIWÉU    kdw  do-nothing      gzip  165905.0       0
# 34                    KAAPOR    urk  do-nothing      gzip  166140.0       0
# 35                   MACUSHI    mac  do-nothing      gzip  167025.0       0
# 36                 GUAJAJARA    gjj  do-nothing      gzip  168750.0       0
# 37                   PALIKÚR    plk  do-nothing      gzip  172542.0       0
# 38                 MUNDURUKÚ    muu  do-nothing      gzip  173143.0       0
# 39                     KUBEO    cub  do-nothing      gzip  173829.0       0
# 40                  YANOMAMI  [guu]  do-nothing      gzip  175208.0       0
# 41                    TERÊNA    trn  do-nothing      gzip  175278.0       0
# 42                 RIKBAKTSA    rik  do-nothing      gzip  175765.0       0
# 43                HIXKARYÁNA    hix  do-nothing      gzip  182554.0       0
# 44                    CULINA    cul  do-nothing      gzip  183766.0       0
# 45                   BAKAIRI    bki  do-nothing      gzip  184943.0       0
# 46                    SANUMÁ    snm  do-nothing      gzip  187155.0       0
# 47                   PAUMARÍ    pau  do-nothing      gzip  187704.0       0
# 48                    CANELA    cnl  do-nothing      gzip  191496.0       0
# 49                  TENHARIM  [pah]  do-nothing      gzip  191654.0       0
# 50                     KAIWÁ    kaw  do-nothing      gzip  195434.0       0
# 51                    KAYAPÓ    kyp  do-nothing      gzip  197169.0       0
# 52                   XAVANTE    xav  do-nothing      gzip  202346.0       0
# 53                    KAYABÍ    kyz  do-nothing      gzip  206107.0       0
# 54                  APINAYÉ    api  do-nothing      gzip  213307.0       0
# 55               SATERÉ-MAWÉ  [mav]  do-nothing      gzip  226951.0       0

# %%
rb
# Out:
#                     language   wals      metric algorithm     value  run_id
# 0                  NHEENGATU  [yrl]  do-nothing       bz2   66662.0       0
# 1                   JAMAMADI    jmm  do-nothing       bz2   72593.0       0
# 2               GUARANI_MBYA  [gun]  do-nothing       bz2   76395.0       0
# 3   GUARANI_EASTERN_BOLIVIAN    crg  do-nothing       bz2   76882.0       0
# 4   GUARANI_WESTERN_BOLIVIAN  [gnw]  do-nothing       bz2   77490.0       0
# 5                   MAXAKALI    max  do-nothing       bz2   79272.0       0
# 6           GUARANI_PARAGUAY    gua  do-nothing       bz2   81419.0       0
# 7                 PORTUGUESE    por  do-nothing       bz2   81811.0       0
# 8                    ENGLISH    eng  do-nothing       bz2   81929.0       0
# 9                  ASHENINKA    cax  do-nothing       bz2   85098.0       0
# 10                    KARAJÁ    jva  do-nothing       bz2   85913.0       0
# 11                    TUYÚCA    tuy  do-nothing       bz2   86061.0       0
# 12                   PARECÍS    pex  do-nothing       bz2   86722.0       0
# 13                    FRENCH    fre  do-nothing       bz2   87026.0       0
# 14                   GERMANY    ger  do-nothing       bz2   87250.0       0
# 15                   KAIGANG    kng  do-nothing       bz2   89080.0       0
# 16                   SPANISH    spa  do-nothing       bz2   90363.0       0
# 17                   SIRIANO    sri  do-nothing       bz2   90549.0       0
# 18             ANCIENT_GREEK  [grc]  do-nothing       bz2   91740.0       0
# 19                    TUCANO    tuc  do-nothing       bz2   92691.0       0
# 20                   APALAÍ    apl  do-nothing       bz2   93445.0       0
# 21                   APURINÃ    apu  do-nothing       bz2   94160.0       0
# 22                    MATSÉS    myr  do-nothing       bz2   96005.0       0
# 23                     NADEB    nad  do-nothing       bz2   96650.0       0
# 24                PIRATAPÚYA    prt  do-nothing       bz2  100023.0       0
# 25                    DESANO    des  do-nothing       bz2  100325.0       0
# 26                    BORÔRO    brr  do-nothing       bz2  100789.0       0
# 27                    TICUNA    tic  do-nothing       bz2  103101.0       0
# 28                    WANANA    gno  do-nothing       bz2  103288.0       0
# 29                   KADIWÉU    kdw  do-nothing       bz2  103702.0       0
# 30                    MAKUNA    mcn  do-nothing       bz2  103879.0       0
# 31                   MACUSHI    mac  do-nothing       bz2  104110.0       0
# 32                 WAPISHANA    wps  do-nothing       bz2  104355.0       0
# 33                 GUAJAJARA    gjj  do-nothing       bz2  104444.0       0
# 34                    KAAPOR    urk  do-nothing       bz2  104727.0       0
# 35                  YAMINÁWA    yam  do-nothing       bz2  105113.0       0
# 36                 KASHINAWA    csh  do-nothing       bz2  107403.0       0
# 37                   PALIKÚR    plk  do-nothing       bz2  107421.0       0
# 38                    TERÊNA    trn  do-nothing       bz2  107893.0       0
# 39                  YANOMAMI  [guu]  do-nothing       bz2  109419.0       0
# 40                HIXKARYÁNA    hix  do-nothing       bz2  109619.0       0
# 41                 MUNDURUKÚ    muu  do-nothing       bz2  113087.0       0
# 42                     KUBEO    cub  do-nothing       bz2  113300.0       0
# 43                 RIKBAKTSA    rik  do-nothing       bz2  113934.0       0
# 44                    CULINA    cul  do-nothing       bz2  115568.0       0
# 45                   BAKAIRI    bki  do-nothing       bz2  115911.0       0
# 46                    SANUMÁ    snm  do-nothing       bz2  117503.0       0
# 47                   PAUMARÍ    pau  do-nothing       bz2  118627.0       0
# 48                    CANELA    cnl  do-nothing       bz2  120900.0       0
# 49                  TENHARIM  [pah]  do-nothing       bz2  124207.0       0
# 50                     KAIWÁ    kaw  do-nothing       bz2  124488.0       0
# 51                   XAVANTE    xav  do-nothing       bz2  126045.0       0
# 52                  APINAYÉ    api  do-nothing       bz2  131158.0       0
# 53                    KAYAPÓ    kyp  do-nothing       bz2  131737.0       0
# 54                    KAYABÍ    kyz  do-nothing       bz2  132390.0       0
# 55               SATERÉ-MAWÉ  [mav]  do-nothing       bz2  143882.0       0

# %% [markdown]
# # H2 Content invariance
# For any complexity measure, Bible complexity should be the same (independenlty of translation).
# In this case, we should observe a smaller variance in size in bytes of the compressed texts in comparison with
# the uncompressed texts.

# %%
def deviation_across_languages(df):
    df2 = df.loc[:, :]
    by = ["metric", "algorithm"]
    m = df.groupby(by=by).value.transform("mean")
    s = df.groupby(by=by).value.transform("std")
    df2['mean'] = m
    df2['std'] = s
    return df2.sort_values('language').reset_index().drop(columns='index')

# %%
daldf = deviation_across_languages(df)

# %%
daldf[(daldf.metric == 'do-nothing') & (daldf.algorithm == 'none')]['std'].unique().item()**2
# Out:
# 53855486665.58525

# %%
daldf[(daldf.metric == 'do-nothing') & (daldf.algorithm == 'gzip')]['std'].unique().item()**2
# Out:
# 738590723.2443149

# %%
daldf[(daldf.metric == 'do-nothing') & (daldf.algorithm == 'bz2')]['std'].unique().item()**2
# Out:
# 284585640.07027817

# %%
sns.histplot(df[(df.metric == 'do-nothing') & (df.algorithm == 'none')], x='value', bins=10)
sns.histplot(df[(df.metric == 'do-nothing') & (df.algorithm == 'gzip')], x='value', bins=10)
sns.histplot(df[(df.metric == 'do-nothing') & (df.algorithm == 'bz2')], x='value', bins=10)
#TODO: Multihistograma
# Out:
# <Axes: xlabel='value', ylabel='Count'>

# %% [markdown]
# # H3 Morphology and Syntatic trade-off
# Languages that have a higher morphological complexity show a smaller syntatic complexity and vice-versa.

# %%
del_chars_gzip = fetch_algorithm(df, 'del-chars', 'gzip') # Morphological
del_chars_bz2  = fetch_algorithm(df, 'del-chars', 'bz2')

del_words_gzip = fetch_algorithm(df, 'del-words', 'gzip') # Syntatic
del_words_bz2 = fetch_algorithm(df, 'del-words', 'bz2')

# %% [markdown]
# ## Caution
# To measure this we can not rely on direct correlation. This is because both complexity measures
# are computed in the same way, which gives a positive correlation. So the proper way of doing the measure
# is computing the correlation between the residuals of two linear regressions one from morphological to syntatic, and other from syntatic to morphological.

# %%
del_chars_gzip['mean'].corr(del_words_gzip['mean'], method='pearson')
# Out:
# 0.454189876665531

# %%
del_chars_bz2['mean'].corr(del_words_bz2['mean'], method='pearson')
# Out:
# 0.4712990142956483

# %%
indo_european_languages = ("ANCIENT_GREEK", "ENGLISH", "FRENCH", "GERMAN", "PORTUGUESE", "SPANISH")

# %%
plt.scatter(del_chars_gzip[del_chars_gzip.language.isin(indo_european_languages)]['mean'],
            del_words_gzip[del_words_gzip.language.isin(indo_european_languages)]['mean'])

# %%
del_chars_gzip[del_chars_gzip.language.isin(indo_european_languages)]['mean'].corr(del_words_gzip[del_words_gzip.language.isin(indo_european_languages)]['mean'], method='pearson')
# Out:
# 0.9293806317393765

# %%
del_chars_gzip[del_chars_gzip.language.isin(indo_european_languages)]['mean'].corr(del_words_gzip[del_words_gzip.language.isin(indo_european_languages)]['mean'], method='spearman')
# Out:
# 0.8999999999999998

# %%
plt.scatter(del_chars_gzip['mean'],
            del_words_gzip['mean'])

# %% [markdown]
# ## Computing the residuals

# %%
x = del_chars_gzip['mean'].to_numpy()
y = del_words_gzip['mean'].to_numpy()

ordered_index = x.argsort()
# Order the points so points with lower x appears first
y = y[ordered_index]
x = x[ordered_index]

# Follow the docs at https://numpy.org/doc/stable/reference/generated/numpy.linalg.lstsq.html
A = np.vstack([x, np.ones(len(x))]).T
B = np.vstack([y, np.ones(len(y))]).T

mx, cx = np.linalg.lstsq(A, y, rcond=None)[0]
my, cy = np.linalg.lstsq(B, x, rcond=None)[0]

plt.scatter(del_chars_gzip['mean'], del_words_gzip['mean'])
plt.plot(x, mx*x + cx, 'r', label='Fitted line')
plt.plot(my*y + cy, y, 'b', label='Other fitted line')

residualsa = mx*x + cx - y
residualsb = my*y + cy - x

corr = sp.stats.pearsonr(residualsa, residualsb)
print("The correlation between the residuals for Gzip compression is %0.4f and the p-value=%g" % (corr.statistic, corr.pvalue))
# Out:
# The correlation between the residuals for Gzip compression is -0.4542 and the p-value=0.000437893

# %%
x = del_chars_bz2['mean'].to_numpy()
y = del_words_bz2['mean'].to_numpy()

ordered_index = x.argsort()
# Order the points so points with lower x appears first
y = y[ordered_index]
x = x[ordered_index]

# Follow the docs at https://numpy.org/doc/stable/reference/generated/numpy.linalg.lstsq.html
A = np.vstack([x, np.ones(len(x))]).T
B = np.vstack([y, np.ones(len(y))]).T

mx, cx = np.linalg.lstsq(A, y, rcond=None)[0]
my, cy = np.linalg.lstsq(B, x, rcond=None)[0]

plt.scatter(del_chars_bz2['mean'], del_words_bz2['mean'])
plt.plot(x, mx*x + cx, 'r', label='Fitted line')
plt.plot(my*y + cy, y, 'b', label='Other fitted line')

residualsa = mx*x + cx - y
residualsb = my*y + cy - x

corr = sp.stats.pearsonr(residualsa, residualsb)
print("The correlation between the residuals for Bzip2 compression is %0.4f and the p-value=%g" % (corr.statistic, corr.pvalue))
# Out:
# The correlation between the residuals for Bzip2 compression is -0.4713 and the p-value=0.000246093

# %% [markdown]
# # O1 Morphological Complexity, tokens and types
# a) There exists a **positive** correlation between morphological complexity and **the number of types** in a sample.
#
# b) There exists a **negative** correlation between morphological complexity and **the number of tokens** in a sample.

# %%
d = compute_numtypes_numtokens(bibles)

tdf = pd.DataFrame(d).sort_values('language')

repwords_gzip = fetch_algorithm(df, 'rep-words', 'gzip').value.to_numpy()
repwords_bz2 = fetch_algorithm(df, 'rep-words', 'bz2').value.to_numpy()
s = "%s) corr=%0.4f, p-value=%g"

print("Gzip results:")
a = sp.stats.pearsonr(tdf.types.to_numpy(), repwords_gzip)#.value.to_numpy())
b = sp.stats.pearsonr(tdf.tokens.to_numpy(), repwords_gzip)#.value.to_numpy())
print(s % ("a", a.statistic, a.pvalue))
print(s % ("b", b.statistic, b.pvalue))

print("\nBz2 results:")
a = sp.stats.pearsonr(tdf.types.to_numpy(), repwords_bz2)#.value.to_numpy())
b = sp.stats.pearsonr(tdf.tokens.to_numpy(), repwords_bz2)#.value.to_numpy())
print(s % ("a", a.statistic, a.pvalue))
print(s % ("b", b.statistic, b.pvalue))
# Out:
# Gzip results:
# a) corr=0.7819, p-value=1.1336e-12
# b) corr=-0.8209, p-value=9.53573e-15
#
# Bz2 results:
# a) corr=0.7614, p-value=9.63016e-12
# b) corr=-0.8349, p-value=1.27415e-15

# %%
gzipi = get_indexes(raw_gzip)
bz2i = get_indexes(raw_bz2)

gzip_series = pd.Series([gzipi[x] for x in sorted(gzipi) ])
bz2_series = pd.Series([bz2i[x] for x in sorted(bz2i)])

r = sp.stats.pearsonr(gzip_series.to_numpy(), bz2_series.to_numpy())
print("Correlation between Gzip and Bz2 is %0.4f and p-value=%g" % (r.statistic, r.pvalue))
# Out:
# Correlation between Gzip and Bz2 is 0.9904 and p-value=4.74541e-48

# %% [markdown]
# # O2 All languages are equal in a pragmatic sense
# The varinace of the pragmatic complexity should be the smallest.

# %%
df2 = fetch_all_metric_algorithms(df)

do_nothing = df2.metric == 'do-nothing'
none = df2.algorithm == 'none'
df3 = df2.loc[~do_nothing & ~none].sort_values("var").reset_index().drop(columns='index')
m = df3.groupby(by=['algorithm', 'metric'])['mean'].transform('mean')
v = df3.groupby(by=['algorithm', 'metric'])['mean'].transform('std')**2
df4 = df3.copy()
df4['mean'] = m
df4['var'] = v
df5 = df4.drop_duplicates(["metric", "algorithm"]).drop(columns=['language', 'wals'])

df5.sort_values('var')
# Out:
#          metric algorithm     value      mean       var
# 282  del-verses      gzip  0.904302  0.904296  0.000002
# 307  del-verses       bz2  0.888515  0.904005  0.000052
# 34    del-words      gzip  0.933770  0.929086  0.000171
# 23    del-words       bz2  0.944746  0.948559  0.000500
# 28    del-chars      gzip  1.206897  1.198566  0.002090
# 49    del-chars       bz2  1.506403  1.413138  0.004775
# 3     rep-words       bz2  0.926799  0.907339  0.013974
# 0     rep-words      gzip  0.667520  0.875757  0.018610

# %% [markdown]
# # O3 Morphological complexity metric agrees with Nichol's

# %%
nichols_complexity = pd.read_csv('../dataset/complexity_ldst.csv', index_col=None)

# %%
def O3(df, nc, languages, metric_str, algorithm_str):
    #df3 = df2[df2.language.isin(languages)]
    langs = df.language.isin(languages)
    metric = df.metric == metric_str
    algorithm = df.algorithm == algorithm_str
    a = df[langs & metric & algorithm].sort_values('language')['mean'].to_numpy()
    b = nc[nc.language.isin(languages)].sort_values('language')['value'].to_numpy()
    #print(len(a), len(b))
    r = sp.stats.pearsonr(a, b)
    print('%r %s %s -> pearsonr=%0.4f p-value=%g' % (languages, metric_str, algorithm_str, r.statistic, r.pvalue))
    #return sp.stats.pearsonr(a, b)

# %%
df2 = fetch_all_metric_algorithms(df)
languages = set(nichols_complexity.language) & set(df.language)

#O3(df2, nichols_complexity, languages, 'rep-words', 'gzip')

O3(df2, nichols_complexity, languages, 'del-chars', 'gzip')

#O3(df2, nichols_complexity, languages, 'rep-words', 'bz2')

O3(df2, nichols_complexity, languages, 'del-chars', 'bz2')

languages = languages - set(["FRENCH"]); print('removing French')

#O3(df2, nichols_complexity, languages, 'rep-words', 'gzip')

O3(df2, nichols_complexity, languages, 'del-chars', 'gzip')

#O3(df2, nichols_complexity, languages, 'rep-words', 'bz2')

O3(df2, nichols_complexity, languages, 'del-chars', 'bz2')
# Out:
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'FRENCH', 'CANELA', 'ENGLISH'} del-chars gzip -> pearsonr=0.0374 p-value=0.943975
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'FRENCH', 'CANELA', 'ENGLISH'} del-chars bz2 -> pearsonr=-0.0352 p-value=0.94723
# removing French
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'CANELA', 'ENGLISH'} del-chars gzip -> pearsonr=0.5689 p-value=0.316904
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'CANELA', 'ENGLISH'} del-chars bz2 -> pearsonr=0.4625 p-value=0.432853

# %%
dff = df.copy()
dff.loc[dff.metric == 'rep-words', 'value'] = 1/dff[dff.metric == 'rep-words']['value']
df3 = fetch_all_metric_algorithms(dff)

languages = set(nichols_complexity.language) & set(dff.language)

O3(df3, nichols_complexity, languages, 'rep-words', 'gzip')

#O3(df3, nichols_complexity, languages, 'del-chars', 'gzip')

O3(df3, nichols_complexity, languages, 'rep-words', 'bz2')

#O3(df3, nichols_complexity, languages, 'del-chars', 'bz2')

languages = languages - set(["FRENCH"]); print('removing French')

O3(df3, nichols_complexity, languages, 'rep-words', 'gzip')

#O3(df3, nichols_complexity, languages, 'del-chars', 'gzip')

O3(df3, nichols_complexity, languages, 'rep-words', 'bz2')

#O3(df3, nichols_complexity, languages, 'del-chars', 'bz2')
# Out:
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'FRENCH', 'CANELA', 'ENGLISH'} rep-words gzip -> pearsonr=0.1216 p-value=0.818481
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'FRENCH', 'CANELA', 'ENGLISH'} rep-words bz2 -> pearsonr=0.1004 p-value=0.849956
# removing French
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'CANELA', 'ENGLISH'} rep-words gzip -> pearsonr=0.2247 p-value=0.716299
# {'KASHINAWA', 'ASHENINKA', 'HIXKARYÁNA', 'CANELA', 'ENGLISH'} rep-words bz2 -> pearsonr=0.2672 p-value=0.663893

# %% [markdown]
# # Compression algorithm approximates Kolgomorov Complexity
# The results are equivalent wheter using **Gzip** or **Bz2**.

# %% [markdown]
# # Correlation between morphological complexities

# %%
df2 = fetch_all_metric_algorithms(df)

# %%
def corr_morph_complex(df):
    repwords = df.metric == 'rep-words'
    delchars = df.metric == 'del-chars'
    gzip = df.algorithm == 'gzip'

    a = df[repwords & gzip]['mean'].to_numpy()
    b = df[delchars & gzip]['mean'].to_numpy()
    plt.scatter(a, b)
    r = sp.stats.pearsonr(a, b)
    return "corr=%0.4f p-value=%g" % (r.statistic, r.pvalue)
    #return df2.drop(columns=['language', 'wals', 'value', 'var']).drop_duplicates(['metric', 'algorithm'])

# %%
corr_morph_complex(df3)
# Out:
# 'corr=0.3281 p-value=0.0135551'

# %%
df3[(df3.metric == 'rep-words') & (df3.algorithm == 'gzip')].sort_values('mean')
# Out:
#                      language   wals     metric algorithm     value      mean  \
# 65                  ASHENINKA    cax  rep-words      gzip  0.748751  0.750028
# 4               ANCIENT_GREEK  [grc]  rep-words      gzip  0.879161  0.879531
# 367                    KARAJÁ    jva  rep-words      gzip  0.903891  0.903527
# 756                    TUYÚCA    tuy  rep-words      gzip  0.930595  0.931550
# 706                    TERÊNA    trn  rep-words      gzip  0.944026  0.943738
# 329                   KADIWÉU    kdw  rep-words      gzip  0.950411  0.950214
# 46                    APURINÃ    apu  rep-words      gzip  0.988701  0.988267
# 249          GUARANI_PARAGUAY    gua  rep-words      gzip  0.996942  0.998073
# 568                   PARECÍS    pex  rep-words      gzip  1.000176  0.999591
# 83                    BAKAIRI    bki  rep-words      gzip  1.004196  1.004819
# 787                 WAPISHANA    wps  rep-words      gzip  1.015190  1.014691
# 740                    TUCANO    tuc  rep-words      gzip  1.044306  1.043483
# 180                   GERMANY    ger  rep-words      gzip  1.053424  1.053174
# 129                    CULINA    cul  rep-words      gzip  1.066846  1.067121
# 684                   SPANISH    spa  rep-words      gzip  1.069368  1.069280
# 660                   SIRIANO    sri  rep-words      gzip  1.071042  1.070121
# 387                 KASHINAWA    csh  rep-words      gzip  1.069613  1.070323
# 577                   PAUMARÍ    pau  rep-words      gzip  1.078991  1.079317
# 611                PORTUGUESE    por  rep-words      gzip  1.081464  1.081552
# 472                    MATSÉS    myr  rep-words      gzip  1.095235  1.094772
# 448                   MACUSHI    mac  rep-words      gzip  1.095207  1.095164
# 425                     KUBEO    cub  rep-words      gzip  1.095674  1.095696
# 525                 NHEENGATU  [yrl]  rep-words      gzip  1.094764  1.096152
# 626                 RIKBAKTSA    rik  rep-words      gzip  1.103257  1.102438
# 351                     KAIWÁ    kaw  rep-words      gzip  1.108487  1.109179
# 18                    APALAÍ    apl  rep-words      gzip  1.116241  1.116985
# 824                  YAMINÁWA    yam  rep-words      gzip  1.117329  1.118075
# 702                  TENHARIM  [pah]  rep-words      gzip  1.119298  1.119569
# 171                    FRENCH    fre  rep-words      gzip  1.120022  1.121114
# 550                   PALIKÚR    plk  rep-words      gzip  1.122550  1.123001
# 155                   ENGLISH    eng  rep-words      gzip  1.134392  1.134472
# 138                    DESANO    des  rep-words      gzip  1.145854  1.145205
# 733                    TICUNA    tic  rep-words      gzip  1.152651  1.152344
# 239              GUARANI_MBYA  [gun]  rep-words      gzip  1.186269  1.186604
# 501                 MUNDURUKÚ    muu  rep-words      gzip  1.189525  1.189909
# 293                  JAMAMADI    jmm  rep-words      gzip  1.190474  1.190651
# 592                PIRATAPÚYA    prt  rep-words      gzip  1.212005  1.212698
# 649               SATERÉ-MAWÉ  [mav]  rep-words      gzip  1.232539  1.232317
# 260  GUARANI_WESTERN_BOLIVIAN  [gnw]  rep-words      gzip  1.233555  1.233571
# 399                    KAYABÍ    kyz  rep-words      gzip  1.237949  1.236866
# 216  GUARANI_EASTERN_BOLIVIAN    crg  rep-words      gzip  1.248284  1.247407
# 456                    MAKUNA    mcn  rep-words      gzip  1.274185  1.273976
# 777                    WANANA    gno  rep-words      gzip  1.276780  1.276183
# 97                     BORÔRO    brr  rep-words      gzip  1.312627  1.312243
# 482                  MAXAKALI    max  rep-words      gzip  1.328494  1.330555
# 838                  YANOMAMI  [guu]  rep-words      gzip  1.336155  1.337715
# 272                HIXKARYÁNA    hix  rep-words      gzip  1.338371  1.338097
# 203                 GUAJAJARA    gjj  rep-words      gzip  1.361630  1.361291
# 406                    KAYAPÓ    kyp  rep-words      gzip  1.381754  1.380421
# 114                    CANELA    cnl  rep-words      gzip  1.473921  1.473235
# 795                   XAVANTE    xav  rep-words      gzip  1.498082  1.498589
# 512                     NADEB    nad  rep-words      gzip  1.499926  1.500702
# 312                    KAAPOR    urk  rep-words      gzip  1.502654  1.503283
# 33                   APINAYÉ    api  rep-words      gzip  1.516082  1.515693
# 338                   KAIGANG    kng  rep-words      gzip  1.557309  1.555945
# 640                    SANUMÁ    snm  rep-words      gzip  1.561283  1.560221
#
#               var
# 65   4.508769e-07
# 4    8.911154e-07
# 367  1.594413e-07
# 756  8.060261e-07
# 706  1.972377e-07
# 329  3.558595e-07
# 46   3.506000e-07
# 249  8.403715e-07
# 568  5.527323e-07
# 83   3.726932e-07
# 787  5.174179e-07
# 740  9.963102e-07
# 180  8.092840e-07
# 129  4.223101e-07
# 684  7.796444e-07
# 660  4.980497e-07
# 387  4.123626e-07
# 577  4.562908e-07
# 611  5.304414e-07
# 472  1.749661e-07
# 448  2.228571e-07
# 425  4.504603e-07
# 525  1.100821e-06
# 626  3.709355e-07
# 351  3.892890e-07
# 18   7.132562e-07
# 824  1.459372e-06
# 702  5.201531e-07
# 171  1.426398e-06
# 550  2.520181e-07
# 155  5.810614e-07
# 138  6.259038e-07
# 733  6.006701e-07
# 239  1.205651e-06
# 501  5.389137e-07
# 293  9.092113e-07
# 592  7.120697e-07
# 649  1.242650e-07
# 260  6.025390e-07
# 399  1.131082e-06
# 216  6.079361e-07
# 456  5.225766e-07
# 777  4.164644e-07
# 97   3.509801e-07
# 482  3.016825e-06
# 838  4.737155e-07
# 272  2.121896e-06
# 203  4.987166e-07
# 406  8.812782e-07
# 114  4.596404e-07
# 795  2.544251e-07
# 512  3.871807e-07
# 312  6.120736e-06
# 33   2.020169e-06
# 338  6.694644e-07
# 640  7.757687e-07

# %%
df3[(df3.metric == 'del-chars') & (df3.algorithm == 'gzip')].sort_values('mean')
# Out:
#                      language   wals     metric algorithm     value      mean  \
# 3               ANCIENT_GREEK  [grc]  del-chars      gzip  1.082752  1.081678
# 605                PORTUGUESE    por  del-chars      gzip  1.097602  1.097952
# 185                   GERMANY    ger  del-chars      gzip  1.102991  1.102323
# 683                   SPANISH    spa  del-chars      gzip  1.107152  1.104547
# 154                   ENGLISH    eng  del-chars      gzip  1.108117  1.106589
# 174                    FRENCH    fre  del-chars      gzip  1.109295  1.109799
# 365                    KARAJÁ    jva  del-chars      gzip  1.141167  1.141855
# 247          GUARANI_PARAGUAY    gua  del-chars      gzip  1.141303  1.142052
# 381                 KASHINAWA    csh  del-chars      gzip  1.161366  1.159207
# 333                   KAIGANG    kng  del-chars      gzip  1.158770  1.160375
# 719                    TERÊNA    trn  del-chars      gzip  1.169091  1.169062
# 231              GUARANI_MBYA  [gun]  del-chars      gzip  1.170761  1.169911
# 86                    BAKAIRI    bki  del-chars      gzip  1.170982  1.170913
# 810                  YAMINÁWA    yam  del-chars      gzip  1.171990  1.173001
# 60                  ASHENINKA    cax  del-chars      gzip  1.178778  1.180946
# 118                    CANELA    cnl  del-chars      gzip  1.184510  1.186128
# 754                    TUYÚCA    tuy  del-chars      gzip  1.187350  1.187837
# 348                     KAIWÁ    kaw  del-chars      gzip  1.191574  1.191189
# 415                    KAYAPÓ    kyp  del-chars      gzip  1.193053  1.193447
# 832                  YANOMAMI  [guu]  del-chars      gzip  1.194032  1.193903
# 146                    DESANO    des  del-chars      gzip  1.197309  1.194892
# 654               SATERÉ-MAWÉ  [mav]  del-chars      gzip  1.193663  1.195135
# 504                 MUNDURUKÚ    muu  del-chars      gzip  1.196912  1.196205
# 520                     NADEB    nad  del-chars      gzip  1.200233  1.200140
# 20                    APALAÍ    apl  del-chars      gzip  1.204067  1.202435
# 790                 WAPISHANA    wps  del-chars      gzip  1.203861  1.203958
# 772                    WANANA    gno  del-chars      gzip  1.204707  1.204734
# 739                    TUCANO    tuc  del-chars      gzip  1.206972  1.206303
# 493                  MAXAKALI    max  del-chars      gzip  1.205581  1.206778
# 537                 NHEENGATU  [yrl]  del-chars      gzip  1.206897  1.206789
# 566                   PARECÍS    pex  del-chars      gzip  1.208611  1.207876
# 545                   PALIKÚR    plk  del-chars      gzip  1.210100  1.210362
# 402                    KAYABÍ    kyz  del-chars      gzip  1.209736  1.210672
# 464                    MAKUNA    mcn  del-chars      gzip  1.213567  1.213494
# 32                   APINAYÉ    api  del-chars      gzip  1.214334  1.214221
# 644                    SANUMÁ    snm  del-chars      gzip  1.215062  1.215514
# 45                    APURINÃ    apu  del-chars      gzip  1.215921  1.217044
# 212  GUARANI_EASTERN_BOLIVIAN    crg  del-chars      gzip  1.217265  1.217813
# 701                  TENHARIM  [pah]  del-chars      gzip  1.219740  1.218705
# 262  GUARANI_WESTERN_BOLIVIAN  [gnw]  del-chars      gzip  1.219010  1.219610
# 433                     KUBEO    cub  del-chars      gzip  1.222696  1.224158
# 673                   SIRIANO    sri  del-chars      gzip  1.226268  1.225390
# 195                 GUAJAJARA    gjj  del-chars      gzip  1.229736  1.228527
# 442                   MACUSHI    mac  del-chars      gzip  1.228900  1.229878
# 724                    TICUNA    tic  del-chars      gzip  1.232385  1.231763
# 622                 RIKBAKTSA    rik  del-chars      gzip  1.236190  1.235863
# 290                  JAMAMADI    jmm  del-chars      gzip  1.236254  1.238289
# 322                   KADIWÉU    kdw  del-chars      gzip  1.239902  1.241028
# 585                PIRATAPÚYA    prt  del-chars      gzip  1.244051  1.245540
# 578                   PAUMARÍ    pau  del-chars      gzip  1.247789  1.249064
# 307                    KAAPOR    urk  del-chars      gzip  1.253569  1.253572
# 133                    CULINA    cul  del-chars      gzip  1.255178  1.255837
# 473                    MATSÉS    myr  del-chars      gzip  1.261073  1.260545
# 99                     BORÔRO    brr  del-chars      gzip  1.262072  1.261372
# 797                   XAVANTE    xav  del-chars      gzip  1.263321  1.263793
# 270                HIXKARYÁNA    hix  del-chars      gzip  1.287126  1.289684
#
#               var
# 3    6.939984e-07
# 605  7.735534e-07
# 185  1.122854e-06
# 683  2.458278e-06
# 154  1.326628e-06
# 174  7.824456e-07
# 365  1.278270e-06
# 247  7.329200e-07
# 381  1.377237e-06
# 333  1.205412e-06
# 719  7.319634e-07
# 231  1.579030e-06
# 86   1.386936e-06
# 810  1.949265e-06
# 60   8.825035e-07
# 118  1.049537e-06
# 754  7.728964e-07
# 348  5.279231e-07
# 415  1.445134e-06
# 832  8.645707e-07
# 146  2.168460e-06
# 654  1.573416e-06
# 504  5.532276e-07
# 520  1.548788e-06
# 20   8.202158e-07
# 790  1.351332e-06
# 772  9.655389e-07
# 739  8.583746e-07
# 493  2.332507e-06
# 537  2.601254e-07
# 566  8.830477e-07
# 545  8.057729e-07
# 402  7.000688e-07
# 464  7.465886e-07
# 32   4.830382e-07
# 644  9.819744e-07
# 45   1.869692e-06
# 212  2.031922e-06
# 701  3.991042e-07
# 262  1.185468e-06
# 433  1.683983e-06
# 673  4.064473e-07
# 195  1.683165e-06
# 442  1.293616e-06
# 724  1.075303e-06
# 622  1.110374e-06
# 290  1.408029e-06
# 322  9.549063e-07
# 585  1.216230e-06
# 578  9.315198e-07
# 307  1.710217e-06
# 133  1.506565e-06
# 473  9.948268e-07
# 99   1.580593e-06
# 797  7.732650e-07
# 270  1.470752e-06

# %%
corr_morph_complex(df2)
# Out:
# 'corr=-0.3447 p-value=0.00928078'

# %%
len(set(df2.language))
# Out:
# 56
